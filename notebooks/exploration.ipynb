# %% [markdown]
# # SupportIQ Exploration Notebook
#
# Run `scripts/download_data.py` before running this notebook.
#
# This notebook covers:
# 1. Loading the dataset
# 2. Identifying top brands
# 3. Exploring `AppleSupport` distribution
# 4. Topic modeling or clustering for intent discovery

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# df = pd.read_csv('../data/raw/twcs.csv', nrows=1000000)
